# %% [markdown]
# **Question1:**
# Use a dictionary to store information about a person you know. Store their first name, last name, age,
# and the city in which they live. You should have keys such as first_name, last_name, age, and city. Print
# each piece of information stored in your dictionary. Add a new key value pair about qualification then
# update the qualification value to high academic level then delete it.

# %%
person = {
    'first_name': 'Muhammad',
    'last_name': 'Farooq',
    'age': 24,
    'city': 'Karachi',
    }

print(person)
print('------------------------------------------------------------------------')
person['qualification'] = 'high academic level'
print('Updated Dictionary',person)
print('------------------------------------------------------------------------')
del person['qualification']
print('New Key Value pair has been deleted from Dictionary',person)
# Out:
# {'first_name': 'Muhammad', 'last_name': 'Farooq', 'age': 24, 'city': 'Karachi'}
# ------------------------------------------------------------------------
# Updated Dictionary {'first_name': 'Muhammad', 'last_name': 'Farooq', 'age': 24, 'city': 'Karachi', 'qualification': 'high academic level'}
# ------------------------------------------------------------------------
# New Key Value pair has been deleted from Dictionary {'first_name': 'Muhammad', 'last_name': 'Farooq', 'age': 24, 'city': 'Karachi'}

# %% [markdown]
# **Question2:**
# Make a dictionary called cities. Use the names of three cities as keys in your dictionary. Create a
# dictionary of information about each city and include the country that the city is in, its approximate
# population, and one fact about that city. The keys for each city’s dictionary should be something like
# country, population, and fact. Print the name of each city and all of the information you have stored
# about it.

# %%
cities = {
    'Karachi': {
        'country': 'Pakistan',
        'population': 6158080,
        'nearby mountains': 'Himaliya',
        },
    'New Dehli': {
        'country': 'India',
        'population': 8767899,
        'nearby mountains': 'alaska range',
        },
    'Beijing': {
        'country': 'china',
        'population': 1003285,
        'nearby mountains': 'mount Emei',
        }
    }

for city, city_info in cities.items():
    country = city_info['country'].title()
    population = city_info['population']
    mountains = city_info['nearby mountains'].title()

    print("\n" + city.title() + " is in " + country + ".")
    print("  It has a population of about " + str(population) + ".")
    print("  The " + mountains + " mountains are nearby.")
# Out:
# Karachi is in Pakistan.
#   It has a population of about 6158080.
#   The Himaliya mountains are nearby.
#
# New Dehli is in India.
#   It has a population of about 8767899.
#   The Alaska Range mountains are nearby.
#
# Beijing is in China.
#   It has a population of about 1003285.
#   The Mount Emei mountains are nearby.

# %% [markdown]
# **Question3:**
# A movie theater charges different ticket prices depending on a person’s age. If a person is under the age
# of 3, the ticket is free, if they are between 3 and 12, the ticket is $10, and if they are over age 12, the
# ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie
# ticket. italicized text

# %%
prompt = "How old are you?"
prompt += "\nEnter 'quit' when you are finished. "

while True:
    age = input(prompt)
    if age == 'quit':
        break
    age = int(age)

    if age < 3:
        print("  You get in free!")
    elif age < 13:
        print("  Your ticket is $10.")
    else:
        print("  Your ticket is $15.")
# Out:
# How old are you?
# Enter 'quit' when you are finished. 43
#   Your ticket is $15.
# How old are you?
# Enter 'quit' when you are finished. 12
#   Your ticket is $10.
# How old are you?
# Enter 'quit' when you are finished. 1
#   You get in free!
# How old are you?
# Enter 'quit' when you are finished. quit

# %% [markdown]
# **Question4:**
# Write a function called favorite_book() that accepts one parameter, title. The function should print a
# message, such as One of my favorite books is Alice in Wonderland. Call the function, making sure to
# include a book title as an argument in the function call.

# %%
def favorite_book(title):
   print(title + " is one of my favorite book.")

favorite_book('The Abstract Wild')
# Out:
# The Abstract Wild is one of my favorite book.

# %% [markdown]
# **Question5:**
# Guess the number game
# Write a program which randomly generate a number between 1 to 30 and ask the user in input field to
# guess the correct number. Give three chances to user guess the number and also give hint to user if
# hidden number is greater or smaller than the number he given to input field.

# %%
import random as rd
i = 3
while i > 0:
    correct_num = rd.randint(1,30)
    user_num = int(input(f"\n\tYou have {i} chances to guess the hidden number (from 1 to 30): "))
    
    if user_num == correct_num:
        print("\t***Congrats ! Correct Guess, You Won*** :)")
        break
    elif user_num > correct_num:
        print("\tYour guess is greater than the hidden number !")
        i -= 1
    elif user_num < correct_num:
        print("\tYour guess is less than the hidden number !")
        i-=1
    elif user_num < 1 or user_num > 30:
        print("\tPlease enter number in range 1 to 30 !")
        
if i == 0:
    print(f"\n\tYou Lost ! :(  Hidden Number was {correct_num}")
# Out:
# 	You have 3 chances to guess the hidden number (from 1 to 30): 12
# 	Your guess is greater than the hidden number !
#
# 	You have 2 chances to guess the hidden number (from 1 to 30): 3
# 	Your guess is greater than the hidden number !
#
# 	You have 1 chances to guess the hidden number (from 1 to 30): 4
# 	Your guess is greater than the hidden number !
#
# 	You Lost ! :(  Hidden Number was 2
